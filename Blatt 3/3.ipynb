# %% [markdown]
# a)
#  Schreiben Sie ein Script und  finden Sie heraus, wieviele Arbeitstage/reguläre Wochentage es zwischen dem 24. 12. 2025 und dem
# 6.01.2026 gibt – generieren Sie die unten angebene Ausgabe. (0,5 Punkte)

# %%
from datetime import date

import pandas as pd

start = date(2025,12,24)
end = date(2026,1,6)

print(start )
print(start.weekday())
print(end.weekday())
index = pd.date_range(start,end)
print(index)

print(len(index))
arbeitstage = pd.bdate_range(start,end)
print(arbeitstage)
print(len(arbeitstage))
# Out:
# 2025-12-24
# 2
# 1
# DatetimeIndex(['2025-12-24', '2025-12-25', '2025-12-26', '2025-12-27',
#                '2025-12-28', '2025-12-29', '2025-12-30', '2025-12-31',
#                '2026-01-01', '2026-01-02', '2026-01-03', '2026-01-04',
#                '2026-01-05', '2026-01-06'],
#               dtype='datetime64[ns]', freq='D')
# 14
# DatetimeIndex(['2025-12-24', '2025-12-25', '2025-12-26', '2025-12-29',
#                '2025-12-30', '2025-12-31', '2026-01-01', '2026-01-02',
#                '2026-01-05', '2026-01-06'],
#               dtype='datetime64[ns]', freq='B')
# 10
