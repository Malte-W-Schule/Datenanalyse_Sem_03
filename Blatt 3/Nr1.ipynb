# %%
import csv
from operator import index
from tarfile import data_filter

import pandas as pd
from pandas import DataFrame
import re

#df = pd.read_csv('countries_population.csv', delim_whitespace=True, index_col=0)# delimiter=" ",
#df = pd.read_csv('countries_population.csv', header=0, index_col=0,thousands=',')
#df = pd.read_csv('countries_population.csv', sep=',',header=None,names=['Country','Population'],index_col=0,quoting="'")


df = pd.read_csv(
    'countries_population.csv',
    header=None,
    names=['Country', 'Population'],
    index_col=0,
    quotechar="'",      # Ländername in '...' korrekt behandeln
    thousands=',',      # Kommas in Zahlen ignorieren
    engine='python'     # nötig bei quotechar
)



print(df.head())
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[93], line 12
#      10         country = country.strip("'")
#      11         # Population: Kommas entfernen, in int umwandeln
# ---> 12         population = int(population.replace(',', ''))
#      13         data.append([country, population])
#      15 # DataFrame erzeugen
#
# ValueError: invalid literal for int() with base 10: "Union' 511434812"
