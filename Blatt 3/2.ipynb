# %%
import pandas as pd
import csv
df = pd.read_csv('bundeslaender.txt',sep=' ')

df["population"] = df["male"]+ df["female"]
df['density'] = df['population']/df['area']*1000
#print(df)
#print(df.head())
print(df)
# Out:
#                       land      area  male  female  population      density
# 0        Baden-Württemberg  35751.65  5271    5465       10736   300.293833
# 1                   Bayern  70551.57  6103    6366       12469   176.735968
# 2                   Berlin    891.85  1660    1736        3396  3807.815216
# 3              Brandenburg  29478.61  1267    1293        2560    86.842629
# 4                   Bremen    404.28   321     342         663  1639.952508
# 5                  Hamburg    755.16   849     894        1743  2308.120133
# 6                   Hessen  21114.79  2983    3109        6092   288.518143
# 7   Mecklenburg-Vorpommern  23180.14   846     861        1707    73.640625
# 8            Niedersachsen  47624.20  3918    4076        7994   167.855838
# 9      Nordrhein-Westfalen  34085.29  8797    9261       18058   529.788657
# 10         Rheinland-Pfalz  19853.36  1990    2069        4059   204.449020
# ...

# %%
bedingung = df['female'] > df['male']
print(df[bedingung])
# Out:
#                       land      area  male  female  population      density
# 0        Baden-Württemberg  35751.65  5271    5465       10736   300.293833
# 1                   Bayern  70551.57  6103    6366       12469   176.735968
# 2                   Berlin    891.85  1660    1736        3396  3807.815216
# 3              Brandenburg  29478.61  1267    1293        2560    86.842629
# 4                   Bremen    404.28   321     342         663  1639.952508
# 5                  Hamburg    755.16   849     894        1743  2308.120133
# 6                   Hessen  21114.79  2983    3109        6092   288.518143
# 7   Mecklenburg-Vorpommern  23180.14   846     861        1707    73.640625
# 8            Niedersachsen  47624.20  3918    4076        7994   167.855838
# 9      Nordrhein-Westfalen  34085.29  8797    9261       18058   529.788657
# 10         Rheinland-Pfalz  19853.36  1990    2069        4059   204.449020
# ...

# %%
bedingung_1000Einwohner_per_SQM = df["density"] > 1000
print(df[bedingung_1000Einwohner_per_SQM])
# Out:
#       land    area  male  female  population      density
# 2   Berlin  891.85  1660    1736        3396  3807.815216
# 4   Bremen  404.28   321     342         663  1639.952508
# 5  Hamburg  755.16   849     894        1743  2308.120133
