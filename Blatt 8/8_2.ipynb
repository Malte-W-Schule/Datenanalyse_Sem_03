# %%
from datetime import datetime

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import pandas as pd
import glob
import os
from pathlib import Path

import seaborn as sns
from keras import Sequential
from matplotlib.pyplot import figure
import pandas as pd
import glob

from sklearn.model_selection import train_test_split
from tensorflow.python.keras.saving.saved_model_experimental import sequential

# %% [markdown]
# Laden  Sie den Datensatz „rawdata_luftqualitaet.csv“ in einen DataFrame. Skalieren Sie die Daten mit dem StandardScaler. Trennen Sie die
# Daten in einen Lern- und Testdatensatz zur Klasssifikation des Labels “state_air_quality“ mit den 3 Klassen 0, 1 und 2. Nutzen Sie alle 5
# Merkmale 'humidity_inside','temperature_inside','co2_inside','temperature_heater‘ und 'temperature_wall_inside‘ im Training.
# a) Erstellen Sie ein sequentielles Modell in Keras mit 2 Dense Layers mit jeweils 60 Neuronen. (1P)
# b) Trainieren Sie das Modell mit mind. 200 Epochen und visualisieren Sie den Anlernprozess mit „Overfitting“ ähnlich wie unten in der

# %%
df = pd.read_csv("rawdata_luftqualitaet.csv")
df.tail()
# Out:
#      humidity_inside  temperature_inside  co2_inside  temperature_heater  \
# 911            37.92              21.714         891              24.312
# 912            37.89              23.263        1165              52.250
# 913            39.82              23.043        1348              48.812
# 914            39.76              23.508        1470              51.375
# 915            40.54              23.812        1701              51.562
#
#      temperature_wall_inside  state_air_quality
# 911                    8.937                  1
# 912                   10.062                  1
# 913                   10.000                  1
# 914                   10.312                  1
# 915                   10.625                  1

# %%
from keras import layers
import keras
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()

features = ['humidity_inside', 'temperature_inside', 'co2_inside', 'temperature_heater', 'temperature_wall_inside']
X = df[features]
y = df['state_air_quality']

x_scaled = scaler.fit_transform(X)

features = pd.DataFrame(x_scaled, columns=features)

X_train, X_test, Y_train, Y_test = train_test_split(x_scaled, y, test_size=0.2, random_state=42)

features.head()
# Out:
#    humidity_inside  temperature_inside  co2_inside  temperature_heater  \
# 0         1.095303           -0.102155    0.461797            0.156128
# 1         1.099779           -0.112450    0.482187            0.122250
# 2         0.938643            0.171019    0.553551            0.046091
# 3         1.098287            0.274661    1.019115            0.113848
# 4         0.916263            0.282211    0.827112            0.105310
#
#    temperature_wall_inside
# 0                 1.111884
# 1                 1.111884
# 2                 1.244219
# 3                 1.332208
# 4                 1.332208

# %%
features.shape
# Out:
# (916, 5)

# %%
# === A ===

model = Sequential([
	layers.Input(shape=(5,)),
	layers.Dense(60),
	layers.Dense(60),
	layers.Dense(3)
])

# %%
from keras.src.callbacks import EarlyStopping

# == calback ==
early_stop = EarlyStopping(
	monitor='val_loss',
	patience=10,
	restore_best_weights=True,
	verbose=1
)

model.compile(
	optimizer='adam',
	loss='sparse_categorical_crossentropy',
	metrics=['accuracy']
)

# %%
history = model.fit(X_train,
					Y_train,
					epochs=200,
					batch_size=256,
					validation_data=(X_test,Y_test),
					callbacks=[early_stop])
# Out:
# Epoch 1/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 52ms/step - accuracy: 0.3566 - loss: 3.4942 - val_accuracy: 0.4402 - val_loss: 2.1526
# Epoch 2/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.4303 - loss: 2.0436 - val_accuracy: 0.5380 - val_loss: 1.6923
# Epoch 3/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.5328 - loss: 1.9039 - val_accuracy: 0.5489 - val_loss: 1.6924
# Epoch 4/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.5519 - loss: 1.7534 - val_accuracy: 0.4837 - val_loss: 1.8493
# Epoch 5/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.5164 - loss: 1.5820 - val_accuracy: 0.5326 - val_loss: 1.6676
# Epoch 6/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.5287 - loss: 1.5340 - val_accuracy: 0.5163 - val_loss: 1.4562
# Epoch 7/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.5464 - loss: 1.4295 - val_accuracy: 0.5489 - val_loss: 1.2567
# Epoch 8/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.5697 - loss: 1.1880 - val_accuracy: 0.6141 - val_loss: 1.1034
# Epoch 9/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.5984 - loss: 1.0460 - val_accuracy: 0.6196 - val_loss: 0.9316
# Epoch 10/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.6025 - loss: 0.9732 - val_accuracy: 0.6413 - val_loss: 0.8420
# Epoch 11/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.6189 - loss: 0.8842 - val_accuracy: 0.6685 - val_loss: 0.8761
# Epoch 12/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.6202 - loss: 0.8518 - val_accuracy: 0.6522 - val_loss: 0.8299
# Epoch 13/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.6107 - loss: 0.8194 - val_accuracy: 0.6522 - val_loss: 0.7571
# Epoch 14/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.6134 - loss: 0.7862 - val_accuracy: 0.6739 - val_loss: 0.7358
# Epoch 15/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.6257 - loss: 0.7667 - val_accuracy: 0.6848 - val_loss: 0.7097
# Epoch 16/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.6257 - loss: 0.7509 - val_accuracy: 0.6685 - val_loss: 0.6965
# Epoch 17/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.6243 - loss: 0.7382 - val_accuracy: 0.6630 - val_loss: 0.6785
# Epoch 18/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.6189 - loss: 0.7245 - val_accuracy: 0.6630 - val_loss: 0.6620
# Epoch 19/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.6107 - loss: 0.7133 - val_accuracy: 0.6576 - val_loss: 0.6524
# Epoch 20/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.6066 - loss: 0.7044 - val_accuracy: 0.6522 - val_loss: 0.6434
# Epoch 21/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.5997 - loss: 0.6989 - val_accuracy: 0.6359 - val_loss: 0.6355
# Epoch 22/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.5984 - loss: 0.6896 - val_accuracy: 0.6304 - val_loss: 0.6226
# Epoch 23/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.5929 - loss: 0.6928 - val_accuracy: 0.6250 - val_loss: 0.6167
# Epoch 24/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.5847 - loss: 0.6740 - val_accuracy: 0.6250 - val_loss: 0.6112
# Epoch 25/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.5792 - loss: 0.6685 - val_accuracy: 0.6141 - val_loss: 0.6063
# Epoch 26/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.5792 - loss: 0.6650 - val_accuracy: 0.6141 - val_loss: 0.6019
# Epoch 27/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.5765 - loss: 0.6604 - val_accuracy: 0.6087 - val_loss: 0.5977
# Epoch 28/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.5724 - loss: 0.6548 - val_accuracy: 0.6087 - val_loss: 0.5939
# Epoch 29/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.5683 - loss: 0.6497 - val_accuracy: 0.6033 - val_loss: 0.5906
# Epoch 30/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.5656 - loss: 0.6496 - val_accuracy: 0.6033 - val_loss: 0.5877
# Epoch 31/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.5628 - loss: 0.6468 - val_accuracy: 0.6033 - val_loss: 0.5849
# Epoch 32/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.5587 - loss: 0.6444 - val_accuracy: 0.5924 - val_loss: 0.5884
# Epoch 33/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.5615 - loss: 0.6543 - val_accuracy: 0.5924 - val_loss: 0.5805
# Epoch 34/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.5587 - loss: 0.6406 - val_accuracy: 0.5924 - val_loss: 0.5787
# Epoch 35/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.5587 - loss: 0.6420 - val_accuracy: 0.5924 - val_loss: 0.5768
# Epoch 36/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.5601 - loss: 0.6405 - val_accuracy: 0.5978 - val_loss: 0.5750
# Epoch 37/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.5574 - loss: 0.6389 - val_accuracy: 0.5978 - val_loss: 0.5732
# Epoch 38/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.5560 - loss: 0.6376 - val_accuracy: 0.5978 - val_loss: 0.5715
# Epoch 39/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.5642 - loss: 0.6447 - val_accuracy: 0.6033 - val_loss: 0.5765
# Epoch 40/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.5820 - loss: 0.6350 - val_accuracy: 0.6087 - val_loss: 0.5829
# Epoch 41/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.5997 - loss: 0.6382 - val_accuracy: 0.6087 - val_loss: 0.5895
# Epoch 42/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.6079 - loss: 0.6397 - val_accuracy: 0.6087 - val_loss: 0.5905
# Epoch 43/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.6161 - loss: 0.6413 - val_accuracy: 0.6196 - val_loss: 0.5906
# Epoch 44/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.6175 - loss: 0.6620 - val_accuracy: 0.6250 - val_loss: 0.5898
# Epoch 45/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.6202 - loss: 0.6623 - val_accuracy: 0.6250 - val_loss: 0.5885
# Epoch 46/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.6202 - loss: 0.6615 - val_accuracy: 0.6250 - val_loss: 0.5868
# Epoch 47/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.6230 - loss: 0.6597 - val_accuracy: 0.6250 - val_loss: 0.5848
# Epoch 48/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.6202 - loss: 0.6576 - val_accuracy: 0.6250 - val_loss: 0.5828
# Epoch 48: early stopping
# Restoring model weights from the end of the best epoch: 38.

# %%
plt.rcdefaults()
plt.style.use('bmh')
plt.rcParams.update({
	'figure.facecolor': 'white',  # Hintergrund des gesamten Bildes
	'axes.facecolor': '#f0f0f0',  # Hintergrund der Plot-Fläche (bmh typisch)
	'text.color': 'white',
	'savefig.facecolor': 'white',  # Beim Speichern weißer Hintergrund
	'axes.titleweight': 'bold',  # Titel immer fett
	'legend.frameon': True,  # Legende mit Rahmen
	'legend.facecolor': 'white'  # Legendenhintergrund weiß
})
sns.set_theme(style="whitegrid")

# %%
import matplotlib.pyplot as plt

# === B ===

plt.figure(figsize=(10, 6))
plt.plot(history.history['loss'], label='Trainingsfehler (Loss)')
plt.plot(history.history['val_loss'], label='Validationsfehler (Loss)')
plt.legend()
plt.show()

# %%
test_loss, test_acc = model.evaluate(X_test, Y_test)
print(f"Test-Genauigkeit: {test_acc:.2f}")
# Out:
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5978 - loss: 0.5715
# Test-Genauigkeit: 0.60

# %%
# === 2 ===
