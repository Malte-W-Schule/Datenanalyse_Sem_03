# %%
from datetime import datetime

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import pandas as pd
import glob
import os
from pathlib import Path

import seaborn as sns
from keras import Sequential
from matplotlib.pyplot import figure
import pandas as pd
import glob

from sklearn.model_selection import train_test_split
from tensorflow.python.keras.saving.saved_model_experimental import sequential

# %% [markdown]
# Laden  Sie den Datensatz „rawdata_luftqualitaet.csv“ in einen DataFrame. Skalieren Sie die Daten mit dem StandardScaler. Trennen Sie die
# Daten in einen Lern- und Testdatensatz zur Klasssifikation des Labels “state_air_quality“ mit den 3 Klassen 0, 1 und 2. Nutzen Sie alle 5
# Merkmale 'humidity_inside','temperature_inside','co2_inside','temperature_heater‘ und 'temperature_wall_inside‘ im Training.
# a) Erstellen Sie ein sequentielles Modell in Keras mit 2 Dense Layers mit jeweils 60 Neuronen. (1P)
# b) Trainieren Sie das Modell mit mind. 200 Epochen und visualisieren Sie den Anlernprozess mit „Overfitting“ ähnlich wie unten in der

# %%
df = pd.read_csv("rawdata_luftqualitaet.csv")
df.tail()
# Out:
#      humidity_inside  temperature_inside  co2_inside  temperature_heater  \
# 911            37.92              21.714         891              24.312
# 912            37.89              23.263        1165              52.250
# 913            39.82              23.043        1348              48.812
# 914            39.76              23.508        1470              51.375
# 915            40.54              23.812        1701              51.562
#
#      temperature_wall_inside  state_air_quality
# 911                    8.937                  1
# 912                   10.062                  1
# 913                   10.000                  1
# 914                   10.312                  1
# 915                   10.625                  1

# %%
from keras import layers
import keras
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()

features = ['humidity_inside', 'temperature_inside', 'co2_inside', 'temperature_heater', 'temperature_wall_inside']
X = df[features]
y = df['state_air_quality']

x_scaled = scaler.fit_transform(X)

features = pd.DataFrame(x_scaled, columns=features)

X_train, X_test, Y_train, Y_test = train_test_split(x_scaled, y, test_size=0.2, random_state=42)

features.head()
# Out:
#    humidity_inside  temperature_inside  co2_inside  temperature_heater  \
# 0         1.095303           -0.102155    0.461797            0.156128
# 1         1.099779           -0.112450    0.482187            0.122250
# 2         0.938643            0.171019    0.553551            0.046091
# 3         1.098287            0.274661    1.019115            0.113848
# 4         0.916263            0.282211    0.827112            0.105310
#
#    temperature_wall_inside
# 0                 1.111884
# 1                 1.111884
# 2                 1.244219
# 3                 1.332208
# 4                 1.332208

# %%
features.shape
# Out:
# (916, 5)

# %%
# === A ===

model = Sequential([
	layers.Input(shape=(5,)),
	layers.Dense(60),
	layers.Dense(60),
	layers.Dense(3)
])

# %%
from keras.src.callbacks import EarlyStopping,ModelCheckpoint

# == calback ==
early_stop = EarlyStopping(
	monitor='val_loss',
	patience=10,
	restore_best_weights=True
)
checkpoint = ModelCheckpoint(filepath="keras_test_model.h5",monitor='val_loss',save_best_only=True)

model.compile(
	optimizer='adam',
	loss='sparse_categorical_crossentropy',
	metrics=['accuracy']
)

# %%
history = model.fit(X_train,
					Y_train,
					epochs=200,
					batch_size=32,
					validation_data=(X_test,Y_test),
					callbacks=[early_stop,checkpoint])
# Out:
# Epoch 1/200
# 18/23 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.4410 - loss: 4.4685
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 40ms/step - accuracy: 0.5587 - loss: 2.4476 - val_accuracy: 0.6848 - val_loss: 0.9949
# Epoch 2/200
# 12/23 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7059 - loss: 0.9522
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.7117 - loss: 0.7693 - val_accuracy: 0.6793 - val_loss: 0.6314
# Epoch 3/200
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.6913 - loss: 0.6844 - val_accuracy: 0.6630 - val_loss: 0.8075
# Epoch 4/200
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.6831 - loss: 0.6581 - val_accuracy: 0.6467 - val_loss: 0.6612
# Epoch 5/200
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.6694 - loss: 0.6246 - val_accuracy: 0.6630 - val_loss: 0.6396
# Epoch 6/200
# 14/23 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6844 - loss: 0.6330
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.6667 - loss: 0.6528 - val_accuracy: 0.6467 - val_loss: 0.6224
# Epoch 7/200
# 14/23 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.6350 - loss: 0.6830
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.6516 - loss: 0.7039 - val_accuracy: 0.6793 - val_loss: 0.6085
# Epoch 8/200
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.6721 - loss: 0.6562 - val_accuracy: 0.6413 - val_loss: 0.6444
# Epoch 9/200
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.6639 - loss: 0.6679 - val_accuracy: 0.6196 - val_loss: 0.6552
# Epoch 10/200
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.6585 - loss: 0.6766 - val_accuracy: 0.6033 - val_loss: 0.6729
# Epoch 11/200
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.6257 - loss: 0.7149 - val_accuracy: 0.5109 - val_loss: 0.8023
# Epoch 12/200
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.4713 - loss: 1.0002 - val_accuracy: 0.4891 - val_loss: 0.9408
# Epoch 13/200
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.4973 - loss: 0.8498 - val_accuracy: 0.5109 - val_loss: 0.8202
# Epoch 14/200
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - accuracy: 0.4945 - loss: 0.8074 - val_accuracy: 0.4891 - val_loss: 1.0698
# Epoch 15/200
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.4577 - loss: 0.9726 - val_accuracy: 0.4728 - val_loss: 1.2185
# Epoch 16/200
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.4495 - loss: 0.9263 - val_accuracy: 0.4457 - val_loss: 0.8060
# Epoch 17/200
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.4413 - loss: 0.8571 - val_accuracy: 0.4620 - val_loss: 0.8240

# %%
plt.rcdefaults()
plt.style.use('bmh')
plt.rcParams.update({
	'figure.facecolor': 'white',  # Hintergrund des gesamten Bildes
	'axes.facecolor': '#f0f0f0',  # Hintergrund der Plot-Fläche (bmh typisch)
	'text.color': 'white',
	'savefig.facecolor': 'white',  # Beim Speichern weißer Hintergrund
	'axes.titleweight': 'bold',  # Titel immer fett
	'legend.frameon': True,  # Legende mit Rahmen
	'legend.facecolor': 'white'  # Legendenhintergrund weiß
})
sns.set_theme(style="whitegrid")

# %%
import matplotlib.pyplot as plt

# === B ===

plt.figure(figsize=(10, 6))
plt.plot(history.history['loss'], label='Trainingsfehler (Loss)')
plt.plot(history.history['val_loss'], label='Validationsfehler (Loss)')
plt.legend()
plt.show()

# %%
test_loss, test_acc = model.evaluate(X_test, Y_test)
print(f"Test-Genauigkeit: {test_acc:.2f}")
# Out:
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.6793 - loss: 0.6085
# Test-Genauigkeit: 0.68

# %%
# === 2 ===
