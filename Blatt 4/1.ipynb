# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as snus

df = pd.read_csv('iris.csv',sep=',')
print(df.head())
# Out:
#    sepal.length  sepal.width  petal.length  petal.width variety
# 0           5.1          3.5           1.4          0.2  Setosa
# 1           4.9          3.0           1.4          0.2  Setosa
# 2           4.7          3.2           1.3          0.2  Setosa
# 3           4.6          3.1           1.5          0.2  Setosa
# 4           5.0          3.6           1.4          0.2  Setosa

# %%
setosa_con = df[df["variety"] == "Setosa"]
versicolor_con = df[df["variety"] == "Versicolor"]
Virginica_con = df[df["variety"]== "Virginica"]

# %%
sepal_length_setosa = setosa_con["sepal.length"]
sepal_length_versicolor = versicolor_con["sepal.length"]
sepal_length_virginica = Virginica_con["sepal.length"]

print(sepal_length_setosa.head())
plt.hist(sepal_length_setosa, color="blue", label="Setosa")
plt.hist(sepal_length_versicolor, color="red", label="Versicolor")
plt.hist(sepal_length_virginica, color="green", label="Virginica")

plt.legend()
plt.show()
# Out:
# 0    5.1
# 1    4.9
# 2    4.7
# 3    4.6
# 4    5.0
# Name: sepal.length, dtype: float64

# %%
petal_with_setosa = setosa_con["petal.width"]
petal_with_versicolor = versicolor_con["petal.width"]
petal_with_virginica = Virginica_con["sepal.width"]

plt.hist(petal_with_setosa, color="blue", label="Setosa")
plt.hist(petal_with_versicolor, color="red", label="Versicolor")
plt.hist(petal_with_virginica, color="green", label="Virginica")
plt.legend
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
petal_length_setosa = setosa_con["petal.length"]
petal_length_versicolor = versicolor_con["petal.length"]
petal_length_virginica = Virginica_con["sepal.length"]

plt.hist(petal_length_setosa, color="blue", label="Setosa")
plt.hist(petal_length_versicolor, color="red", label="Versicolor")
plt.hist(petal_length_virginica, color="green", label="Virginica")
plt.legend
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
sepal_wdth_setosa = setosa_con["sepal.width"]
sepal_wdth_versicolor = versicolor_con["sepal.width"]
sepal_wdth_virginica = Virginica_con["sepal.width"]

plt.hist(sepal_wdth_setosa, color="blue", label="Setosa")
plt.hist(sepal_wdth_versicolor, color="red", label="Versicolor")
plt.hist(sepal_wdth_virginica, color="green", label="Virginica")
plt.legend
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>
